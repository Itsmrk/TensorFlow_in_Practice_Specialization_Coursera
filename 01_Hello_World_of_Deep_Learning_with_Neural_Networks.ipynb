# %% [markdown]
# <a href="https://colab.research.google.com/github/Itsmrk/TensorFlow_in_Practice_Specialization_Coursera/blob/master/01_Hello_World_of_Deep_Learning_with_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hello World of Deep Learning with Neural Networks**

# %% [markdown]
# # **Imports**

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# # **Define and Compile the Neural Network**

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd' , loss= 'mean_squared_error')

# %% [markdown]
# # Providing the Data

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %%
model.fit(xs,ys , epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 38.7559
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 30.8412
# Epoch 3/500
# 1/1 [==============================] - 0s 991us/step - loss: 24.6070
# Epoch 4/500
# 1/1 [==============================] - 0s 984us/step - loss: 19.6953
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 15.8240
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 12.7716
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 10.3634
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4624
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.9603
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.7724
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8317
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0856
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.977835]]
